# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from src.preprocessing.taxonomy_mapper import (
    map_category,
    is_supported,
)

# %%
print(map_category("shirt, blouse"))

print(map_category("shoe"))

print(map_category("sleeve"))

print(is_supported("dress"))

print(is_supported("zipper"))
# Out:
# Shirt
# Shoes
# None
# True
# False
