# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from src.preprocessing.category_filter import CategoryFilter

filterer = CategoryFilter()

# %%
annotations = [

    {
        "category": "shirt, blouse"
    },

    {
        "category": "shoe"
    },

    {
        "category": "zipper"
    },

    {
        "category": "pocket"
    },

    {
        "category": "dress"
    }

]

# %%
result = filterer.filter_annotations(
    annotations
)

result
# Out:
# [{'category': 'shirt, blouse', 'akp_category': 'Shirt'},
#  {'category': 'shoe', 'akp_category': 'Shoes'},
#  {'category': 'dress', 'akp_category': 'Dress'}]
