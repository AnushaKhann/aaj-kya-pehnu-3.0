# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.data.scanner import DatasetScanner

scanner = DatasetScanner("../data/sample")

image_paths, labels, classes = scanner.scan()

print("Classes:", classes)
print("Images:", len(image_paths))
print("First Image:", image_paths[0])
print("First Label:", labels[0])
# Out:
# Classes: ['dress', 'jeans', 'shirt', 'shoes', 't-shirt']
# Images: 10
# First Image: ../data/sample/dress/dress2.webp
# First Label: dress
