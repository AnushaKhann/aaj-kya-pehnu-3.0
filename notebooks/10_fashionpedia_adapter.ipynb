# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.datasets.fashionpedia_adapter import FashionpediaAdapter

adapter = FashionpediaAdapter(
    PROJECT_ROOT /
    "data/raw/fashionpedia/annotations/instances_attributes_val2020.json"
)

adapter.build_lookup_tables()

sample = adapter.get_annotation(0)

sample
# Out:
# {'image_id': 17039,
#  'category': 'sleeve',
#  'attributes': ['wrist-length', 'set-in sleeve'],
#  'bbox': [391.0, 460.0, 75.0, 193.0],
#  'segmentation': [[434,
#    650,
#    428,
#    649,
#    426,
#    642,
#    419,
#    636,
#    412,
#    627,
#    406,
#    617,
#    397,
#    603,
#    393,
#    589,
#    391,
#    576,
#    392,
#    556,
#    398,
#    536,
#    405,
#    518,
#    415,
#    491,
#    419,
#    482,
#    423,
#    472,
#    427,
#    465,
#    435,
#    460,
#    434,
#    465,
#    435,
#    474,
#    441,
#    485,
#    444,
#    494,
#    446,
#    506,
#    448,
#    522,
#    450,
#    533,
#    445,
#    548,
#    444,
#    569,
#    439,
#    575,
#    441,
#    579,
#    441,
#    586,
#    445,
#    592,
#    448,
#    595,
#    466,
#    618,
#    460,
#    624,
#    451,
#    633,
#    445,
#    639,
#    444,
#    638,
#    442,
#    648,
#    443,
#    653,
#    437,
#    652]]}
