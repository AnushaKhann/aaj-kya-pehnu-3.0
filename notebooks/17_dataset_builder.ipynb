# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from datasets import load_dataset

fashionpedia = load_dataset(
    "detection-datasets/fashionpedia"
)

# %%
from src.preprocessing.dataset_builder import AKPDatasetBuilder

category_names = fashionpedia["train"].features[
    "objects"
]["category"].feature.names

builder = AKPDatasetBuilder(
    output_dir="../data/processed/akp_v1",
    category_names=category_names
)

builder.create_directories()

# %%
builder.build(
    fashionpedia["train"],
    limit=10
)
# Out:
# Building AKP Dataset: 100%|██████████| 10/10 [00:00<00:00, 68.37it/s]
# Processed 10 samples.

# %%
sample = fashionpedia["train"][0]

print(sample["objects"]["category"])
# Out:
# [23, 23, 33, 10]

# %%
features = fashionpedia["train"].features

print(features["objects"]["category"])
# Out:
# List(ClassLabel(names=['shirt, blouse', 'top, t-shirt, sweatshirt', 'sweater', 'cardigan', 'jacket', 'vest', 'pants', 'shorts', 'skirt', 'coat', 'dress', 'jumpsuit', 'cape', 'glasses', 'hat', 'headband, head covering, hair accessory', 'tie', 'glove', 'watch', 'belt', 'leg warmer', 'tights, stockings', 'sock', 'shoe', 'bag, wallet', 'scarf', 'umbrella', 'hood', 'collar', 'lapel', 'epaulette', 'sleeve', 'pocket', 'neckline', 'buckle', 'zipper', 'applique', 'bead', 'bow', 'flower', 'fringe', 'ribbon', 'rivet', 'ruffle', 'sequin', 'tassel']))

# %%
features = fashionpedia["train"].features

print(features["objects"])
# Out:
# {'bbox_id': List(Value('int64')), 'category': List(ClassLabel(names=['shirt, blouse', 'top, t-shirt, sweatshirt', 'sweater', 'cardigan', 'jacket', 'vest', 'pants', 'shorts', 'skirt', 'coat', 'dress', 'jumpsuit', 'cape', 'glasses', 'hat', 'headband, head covering, hair accessory', 'tie', 'glove', 'watch', 'belt', 'leg warmer', 'tights, stockings', 'sock', 'shoe', 'bag, wallet', 'scarf', 'umbrella', 'hood', 'collar', 'lapel', 'epaulette', 'sleeve', 'pocket', 'neckline', 'buckle', 'zipper', 'applique', 'bead', 'bow', 'flower', 'fringe', 'ribbon', 'rivet', 'ruffle', 'sequin', 'tassel'])), 'bbox': List(List(Value('float64'), length=4)), 'area': List(Value('int64'))}

# %%
print(type(features["objects"]["category"]))
print(features["objects"]["category"])
# Out:
# <class 'datasets.features.features.List'>
# List(ClassLabel(names=['shirt, blouse', 'top, t-shirt, sweatshirt', 'sweater', 'cardigan', 'jacket', 'vest', 'pants', 'shorts', 'skirt', 'coat', 'dress', 'jumpsuit', 'cape', 'glasses', 'hat', 'headband, head covering, hair accessory', 'tie', 'glove', 'watch', 'belt', 'leg warmer', 'tights, stockings', 'sock', 'shoe', 'bag, wallet', 'scarf', 'umbrella', 'hood', 'collar', 'lapel', 'epaulette', 'sleeve', 'pocket', 'neckline', 'buckle', 'zipper', 'applique', 'bead', 'bow', 'flower', 'fringe', 'ribbon', 'rivet', 'ruffle', 'sequin', 'tassel']))

# %%
category_feature = features["objects"]["category"]

print(dir(category_feature))
# Out:
# ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', '_type', 'feature', 'id', 'length', 'pa_type']

# %%
category_names = fashionpedia["train"].features[
    "objects"
]["category"].feature.names

print(category_names[:5])
# Out:
# ['shirt, blouse', 'top, t-shirt, sweatshirt', 'sweater', 'cardigan', 'jacket']
