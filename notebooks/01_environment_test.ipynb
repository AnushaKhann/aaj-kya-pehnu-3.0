# %%
import sys

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
from src.configs.settings import *

print(PROJECT_ROOT)

print(DATA_DIR)

print(CHECKPOINT_DIR)

print(DEVICE)
# Out:
# /Users/anushakhan/Desktop/aaj-kya-pehnu-3.0
# /Users/anushakhan/Desktop/aaj-kya-pehnu-3.0/data
# /Users/anushakhan/Desktop/aaj-kya-pehnu-3.0/models/checkpoints
# mps

# %%
from src.utils.system import print_system_info

print_system_info()
# Out:
# ============================================================
# Operating System : Darwin
# Machine          : arm64
# Python           : 3.11.15
# PyTorch          : 2.12.1
# MPS Available    : True
# ============================================================
