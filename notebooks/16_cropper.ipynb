# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from PIL import Image

from src.preprocessing.cropper import GarmentCropper

# %%
image = Image.open("../data/sample/shirt/shirt1.webp")
image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1000x1500>

# %%
cropper = GarmentCropper()

bbox = [
    50,
    40,
    180,
    220
]

cropped = cropper.crop(
    image,
    bbox
)

cropped
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
from pathlib import Path

cropper.save(
    cropped,
    Path("../data/processed/test_crop.jpg")
)
